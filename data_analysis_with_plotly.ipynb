# %%
import plotly.express as px
import plotly.io as pio
import plotly.offline as py
py.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly.figure_factory import create_table
import matplotlib.pyplot as plt
# %matplotlib inline

pio.renderers.default = "png"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
canada_data = px.data.gapminder().query("country == 'Afghanistan'")

# %%
fig = px.bar(canada_data,  x='year', y='lifeExp', height=400)
fig.show()

# %%
new_data = gapminder[gapminder['year'] == 2007]

# %%
px.bar(canada_data,  x='year',y='pop', color='lifeExp', height=400)

# %%
px.scatter(new_data, x='gdpPercap', y='lifeExp', color='continent', height=500)

# %%
px.scatter(new_data, x='gdpPercap', y='lifeExp', color='continent',size='pop', size_max=60, height=500)

# %%
px.scatter(gapminder, x = 'gdpPercap', y = 'lifeExp', color='continent', size='pop', height=500, size_max=60, hover_name='country', facet_col='continent', log_x=True)

# %%
px.scatter(gapminder, x = 'gdpPercap', y = 'lifeExp', color='continent', size='pop', height=1000, size_max=60, hover_name='country', facet_col='continent', log_x=True, animation_frame='year', animation_group='country')

# %%
px.choropleth(gapminder, locations='iso_alpha', color='lifeExp',height=700, hover_name='country', animation_frame='year', color_continuous_scale=px.colors.sequential.Plasma, projection='natural earth')
